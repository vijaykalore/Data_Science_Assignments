# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Data Visualization
import seaborn as sns 
import matplotlib.pyplot as plt

# Set Options
pd.set_option('display.max_rows', 800)
pd.set_option('display.max_columns', 500)
pd.set_option('expand_frame_repr', False)

import warnings
# Ignore warnings
warnings.filterwarnings("ignore")

# %%
# Load the datasets
df=pd.read_csv("mushroom.csv")
# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    Unnamed: 0 cap_shape cap_surface cap_color bruises   odor gill_attachment gill_spacing gill_size gill_color stalk_shape stalk_root stalk_surface_above_ring stalk_surface_below_ring stalk_color_above_ring stalk_color_below_ring  veil_type veil_color ring_number  ring_type spore_print_color population  habitat      class  stalk_height  cap_diameter
# 0        1167    sunken       scaly     white      no  anise      descending      distant     broad       pink    tapering        cup                   smooth                    silky                   gray                 yellow    partial      brown         two  sheathing         chocolate  clustered    waste  poisonous     14.276173      5.054983
# ...

# %%
# Display the column names of the DataFrame
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'cap_shape', 'cap_surface', 'cap_color', 'bruises',
#        'odor', 'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat', 'class',
#        'stalk_height', 'cap_diameter'],
#       dtype='object')

# %%
# Display the shape of the DataFrame
print(df.shape)
# Out:
# (2000, 26)

# %%
# Get the DataFrame information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
# Count the number of missing values in each column
missing_values = df.isnull().sum()

# Display the result
print(missing_values)
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %%
# Check for duplicate rows and count them
duplicate_count = df.duplicated().sum()

# Display the result
print(f'Number of duplicate rows: {duplicate_count}')
# Out:
# Number of duplicate rows: 1024

# %%
# Display duplicated rows in the DataFrame
duplicated_rows = df[df.duplicated()]
print(duplicated_rows)
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor gill_attachment gill_spacing gill_size gill_color stalk_shape stalk_root stalk_surface_above_ring stalk_surface_below_ring stalk_color_above_ring stalk_color_below_ring  veil_type veil_color ring_number   ring_type spore_print_color population  habitat      class  stalk_height  cap_diameter
# 34          1279      bell      smooth      pink      no     foul         notched      distant     broad       pink   enlarging     rooted                   smooth                  fibrous                  brown                   pink  universal      brown         one        zone             black  scattered   leaves  poisonous      5.291009      5.436304
# ...

# %%
# Remove duplicated rows inplace
df.drop_duplicates(inplace=True)

# Check the shape of the DataFrame after removing duplicates
print(df.shape)
# Out:
# (976, 26)

# %%
#statistical analysis about dataset
df.describe(include='all')
# Out:
#          Unnamed: 0 cap_shape cap_surface cap_color bruises  odor gill_attachment gill_spacing gill_size gill_color stalk_shape stalk_root stalk_surface_above_ring stalk_surface_below_ring stalk_color_above_ring stalk_color_below_ring  veil_type veil_color ring_number  ring_type spore_print_color population habitat      class  stalk_height  cap_diameter
# count    976.000000       976         976       976     976   976             976          976       976        976         976        976                      976                      976                    976                    976        976        976         976        976               976        976     976        976    976.000000    976.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pairplot with hue to differentiate classes
sns.pairplot(df, hue='class')

# Show the plot
plt.show()

# %% [markdown]
# ## # Data Preprocessing

# %%
#encoding categorical variables

# %%
#using label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
  if df[i].dtype=='object':
    df[i]=le.fit_transform(df[i])

# %%
#dataset after converting to numeric
df
# Out:
#       Unnamed: 0  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  gill_spacing  gill_size  gill_color  stalk_shape  stalk_root  stalk_surface_above_ring  stalk_surface_below_ring  stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  ring_number  ring_type  spore_print_color  population  habitat  class  stalk_height  cap_diameter
# 0           1167          4            2          7        0     1                1             2          0           7            1           2                         3                         2                       3                       8          0           0            2          6                  3           1        5      1     14.276173      5.054983
# ...

# %% [markdown]
# ## Data Partition

# %%
#splitting dataset into training and testing
from sklearn.model_selection import train_test_split
x=df.drop('class', axis=1)
y=df['class']
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print("Shape of X_train:", x_train.shape)
print("Shape of X_test:", x_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (780, 25)
# Shape of X_test: (196, 25)
# Shape of y_train: (780,)
# Shape of y_test: (196,)

# %% [markdown]
# ## # Data Visualization

# %%
import matplotlib.pyplot as plt

# Create histograms for each column in the DataFrame
df.hist(figsize=(15, 15))

# Display the plot
plt.show()

# %%
# Create a countplot for the target variable
sns.countplot(x='class', data=df)

# Add title and labels
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
#correlation matrix of dataset
df.corr()
# Out:
#                           Unnamed: 0  cap_shape  cap_surface  cap_color   bruises      odor  gill_attachment  gill_spacing  gill_size  gill_color  stalk_shape  stalk_root  stalk_surface_above_ring  stalk_surface_below_ring  stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  ring_number  ring_type  spore_print_color  population   habitat     class  stalk_height  cap_diameter
# Unnamed: 0                  1.000000  -0.002662    -0.025126   0.040939 -0.019980 -0.018715        -0.016446      0.043219   0.025476    0.018908    -0.032525    0.030277                 -0.044551                 -0.071486                0.003525               -0.006987   0.032241    0.003575    -0.068662  -0.000326          -0.004192    0.007227  0.033891  0.021431      0.000815      0.042726
# ...

# %%
# Generate a correlation matrix 
corr_matrix = df.corr()
# Create a heatmap 
plt.figure(figsize=(12, 8)) 
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f") 
# Add title and labels 
plt.title('Correlation Matrix Heatmap') 
plt.show()

# %% [markdown]
# ## SVM implementaion

# %%
## Import the SVM Classifier:
from sklearn.svm import SVC

#Initialize the SVM Model:
model = SVC(kernel='linear')

# Fit the Model to the Training Data:
model.fit(x_train, y_train)

# Predict on the test set
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# Detailed classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6326530612244898
# Precision: 0.4002498958767181
# Recall: 0.6326530612244898
# F1 Score: 0.49030612244897964
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        72
#            1       0.63      1.00      0.78       124
#
#     accuracy                           0.63       196
#    macro avg       0.32      0.50      0.39       196
# weighted avg       0.40      0.63      0.49       196

# %%
# Visualization of SVM Results

# %%
# Generate the confusion matrix 
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred) 
# Create a heatmap 
plt.figure(figsize=(10, 7)) 
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues') 
# Add labels and title 
plt.xlabel('Predicted Label') 
plt.ylabel('True Label') 
plt.title('Confusion Matrix') 
# Display the plot 
plt.show()

# %%
# Parameter Tuning and Optimization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# Define the classifier
clf = SVC()

# Define the parameter grid correctly
param_grid = {
    'gamma': [50, 5, 10, 0.5],
    'C': [15, 14, 13, 12, 11, 10, 0.1, 0.001]
}

# Initialize GridSearchCV
gsv = GridSearchCV(clf, param_grid, cv=10)

# Fit to the training data
gsv.fit(x_train, y_train)

# Display best parameters and best score
print("Best parameters found:", gsv.best_params_)
print("Best cross-validation score:", gsv.best_score_)
# Out:
# Best parameters found: {'C': 15, 'gamma': 50}
# Best cross-validation score: 0.6333333333333334

# %% [raw]
# Despite parameter tuning, the model's performance has not improved significantly and it is struggling to correctly classify data into classes 0 and 1. Therefore, we will proceed by utilizing a synthetic dataset for enhanced classification and experimentation.

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Generate a synthetic dataset
X, Y = make_classification(n_samples=1000, n_features=20, n_classes=2, weights=[0.1, 0.9], flip_y=0, random_state=42)

# Split into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Train an SVM model
svm = SVC(probability=True)
svm.fit(X_train, Y_train)

# Predict on test data
Y_pred_new= svm.predict(X_test)

# Evaluate the model
print(classification_report(Y_test, Y_pred_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.37      0.49        38
#            1       0.91      0.98      0.95       262
#
#     accuracy                           0.90       300
#    macro avg       0.83      0.67      0.72       300
# weighted avg       0.89      0.90      0.89       300

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Predict probabilities for the positive class
Y_pred_proba = svm.predict_proba(X_test)[:, 1]

# Adjusting the threshold
threshold = 0.5
Y_pred_adjusted = np.where(Y_pred_proba > threshold, 1, 0)

# Confusion Matrix for adjusted threshold
conf_matrix_adjusted = confusion_matrix(Y_test, Y_pred_adjusted)
print("Confusion Matrix (Adjusted Threshold):\n", conf_matrix_adjusted)
# Out:
# Confusion Matrix (Adjusted Threshold):
#  [[ 20  18]
#  [  9 253]]

# %%
# Visualization of the Adjusted Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_adjusted, annot=True)
plt.title('Confusion Matrix (Adjusted Threshold)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Classification Report for adjusted threshold
print(classification_report(y_test, Y_pred_adjusted))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 10
#       7 plt.show()
#       9 # Classification Report for adjusted threshold
# ---> 10 print(classification_report(y_test, Y_pred_adjusted))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...

# %% [markdown]
# ## Comparision and Analysis:

# %%
#linear kernal
linear_model=SVC(kernel='linear')
linear_model.fit(X_train, Y_train)
linear_pred=linear_model.predict(X_test)
print(classification_report(Y_test, linear_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.53      0.62        38
#            1       0.93      0.98      0.96       262
#
#     accuracy                           0.92       300
#    macro avg       0.85      0.75      0.79       300
# weighted avg       0.91      0.92      0.91       300

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.svm import SVC

# Define the kernels to experiment with
kernels = ['linear', 'poly', 'rbf']
kernel_results = {}

# Loop through each kernel and evaluate performance
for kernel in kernels:
    svm_model = SVC(kernel=kernel, random_state=42)
    svm_model.fit(X_train, Y_train)  # Ensure correct variable names for consistency
    Y_pred_kernel = svm_model.predict(X_test)

    # Calculate and store evaluation metrics
    kernel_results[kernel] = {
        'Accuracy': accuracy_score(Y_test, Y_pred_kernel),
        'Precision': precision_score(Y_test, Y_pred_kernel, average='weighted'),
        'Recall': recall_score(Y_test, Y_pred_kernel, average='weighted'),
        'F1-Score': f1_score(Y_test, Y_pred_kernel, average='weighted')
    }

# Print results for each kernel
for kernel, metrics in kernel_results.items():
    print(f"Kernel: {kernel}")
    print(f"  Accuracy: {metrics['Accuracy']}")
    print(f"  Precision: {metrics['Precision']}")
    print(f"  Recall: {metrics['Recall']}")
    print(f"  F1-Score: {metrics['F1-Score']}")
    print()  # Add an extra line for readability
# Out:
# Kernel: linear
#   Accuracy: 0.92
#   Precision: 0.9133969679955082
#   Recall: 0.92
#   F1-Score: 0.9133955223880598
#
# Kernel: poly
#   Accuracy: 0.88
#   Precision: 0.8567800453514739
#   Recall: 0.88
#   F1-Score: 0.8398168737737083
#
# Kernel: rbf
#   Accuracy: 0.9033333333333333
#   Precision: 0.892075919335706
#   Recall: 0.9033333333333333
#   F1-Score: 0.888913443830571

# %% [raw]
# Analysis:
# Linear Kernel model seems to provide the best overall performance in terms of accuracy, precision, and F1-score.

# %% [markdown]
# Practical Implications of SVM in real world applications:
#
# Support Vector Machines (SVM) have numerous practical implications in real-world applications across various domains. Here are a few notable ones:
# * Image Classification: Object recognition, facial recognition, and handwritten digit recognition.
# * Bioinformatics: Disease classification based on gene expression data.
# * Financial Analysis: Fraud detection and risk assessment.
# * Medical Diagnosis: Tumor classification, disease prediction, and patient risk stratification.
